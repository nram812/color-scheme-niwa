# %%
import xarray as xr

# %%
rad = r"C:/Users/rampaln/OneDrive - NIWA/Python Tools/gridded_vcsn_radition.nc"
tmean = r"C:/Users/rampaln/OneDrive - NIWA/Python Tools/VCSN/MeanTemperature.nc"
smd = r"C:/Users/rampaln/OneDrive - NIWA/Python Tools/gridded_vcsn_Soil_Moisture.nc"
rain = r"C:/Users/rampaln/OneDrive - NIWA/Python Tools/gridded_vcsn_Rain_1973-1-1_2020-07-17.nc"

# %%
df = xr.open_dataset(rain)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\Machine_Learning\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     197             try:
# --> 198                 file = self._cache[self._key]
#     199             except KeyError:
#
# ~\Anaconda3\envs\Machine_Learning\lib\site-packages\xarray\backends\lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Users\\rampaln\\OneDrive - NIWA\\Python Tools\\gridded_vcsn_Rain_1973-1-1_2020-07-17.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
vars = [tmean, smd, rain]
# n_dset = xr.Dataset()
for var in vars:
    df = xr.open_dataset(var)
    # n_dset[var] = df[df.data_vars].isel(time = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\Machine_Learning\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     197             try:
# --> 198                 file = self._cache[self._key]
#     199             except KeyError:
#
# ~\Anaconda3\envs\Machine_Learning\lib\site-packages\xarray\backends\lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Users\\rampaln\\OneDrive - NIWA\\Python Tools\\gridded_vcsn_Soil_Moisture.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...
